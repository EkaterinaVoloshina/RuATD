# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix

# %%
def confusion(united, text):
    matrix = confusion_matrix(united['labels'], united['predictions'])
    labels = sorted(united['labels'].unique())
    plt.figure(figsize = (20,14))
    sns.heatmap(matrix, annot=True, 
                xticklabels=labels,
                yticklabels=labels)
    plt.title(f'Confusion matrix for {text}')
    plt.show()

# %% [markdown]
# ## FNN

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/RuATD/FNN_features.csv')

# %%
confusion(df,'FNN')

# %%
print('***RESULTS FNN***')
print(classification_report(df['labels'], df['predictions']))
# Out:
# ***RESULTS FNN***
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                      precision    recall  f1-score   support
#
#              M-BART       0.30      0.32      0.31       418
#            M-BART50       0.28      0.57      0.38      1986
#             M2M-100       0.32      0.01      0.01      1804
#             OPUS-MT       0.20      0.43      0.27      2014
# ...

# %%
figure = plt.figure(figsize=(10, 4))
plt.hist([df['labels'], df['predictions']], label=['target', 'predictions'])
plt.xlabel('Classes')
plt.ylabel('The number of sentences')
plt.title('FNN')
plt.legend(loc='upper left')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Random forest

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/RuATD/Random_Forest_features.csv')

# %%
confusion(df,'Random Forest')

# %%
print('***RESULTS Random Forest***')
print(classification_report(df['labels'], df['predictions']))
# Out:
# ***RESULTS Random Forest***
#                      precision    recall  f1-score   support
#
#              M-BART       0.42      0.34      0.38       418
#            M-BART50       0.30      0.38      0.34      1986
#             M2M-100       0.22      0.24      0.23      1804
#             OPUS-MT       0.24      0.31      0.27      2014
#           mT5-Large       0.11      0.07      0.09       810
#           mT5-Small       0.10      0.05      0.06       490
#        ruGPT2-Large       0.19      0.18      0.19       395
#        ruGPT3-Large       0.31      0.35      0.33      1645
#       ruGPT3-Medium       0.33      0.26      0.29      1170
#        ruGPT3-Small       0.32      0.25      0.28      1155
#           ruT5-Base       0.51      0.58      0.54       440
# ruT5-Base-Multitask       0.06      0.03      0.04       370
#          ruT5-Large       0.10      0.04      0.06       290
#
#            accuracy                           0.27     12987
# ...

# %%
figure = plt.figure(figsize=(10, 4))
plt.hist([df['labels'], df['predictions']], label=['target', 'predictions'])
plt.xlabel('Classes')
plt.ylabel('The number of sentences')
plt.title('Random forest')
plt.legend(loc='upper left')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Log Reg

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/RuATD/LogReg_features.csv')

# %%
confusion(df,'LofReg')

# %%
print('***RESULTS LogReg***')
print(classification_report(df['labels'], df['predictions']))
# Out:
# ***RESULTS LogReg***
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                      precision    recall  f1-score   support
#
#              M-BART       0.12      0.01      0.01       418
#            M-BART50       0.26      0.40      0.32      1986
#             M2M-100       0.12      0.03      0.05      1804
#             OPUS-MT       0.21      0.51      0.29      2014
# ...

# %%
figure = plt.figure(figsize=(10, 4))
plt.hist([df['labels'], df['predictions']], label=['target', 'predictions'])
plt.xlabel('Classes')
plt.ylabel('The number of sentences')
plt.title('Logreg')
plt.legend(loc='upper left')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## CNN

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/RuATD/CNN_character.csv')

# %%
confusion(df,'CNN')

# %%
print('***RESULTS CNN***')
print(classification_report(df['labels'], df['predictions']))
# Out:
# ***RESULTS CNN***
#                      precision    recall  f1-score   support
#
#              M-BART       0.25      0.72      0.38       418
#            M-BART50       0.37      0.66      0.48      1986
#             M2M-100       0.37      0.06      0.11      1804
#             OPUS-MT       0.35      0.23      0.28      2014
#           mT5-Large       0.21      0.11      0.15       810
#           mT5-Small       0.23      0.26      0.24       490
#        ruGPT2-Large       0.33      0.75      0.46       395
#        ruGPT3-Large       0.73      0.40      0.52      1645
#       ruGPT3-Medium       0.51      0.60      0.55      1170
#        ruGPT3-Small       0.56      0.37      0.45      1155
#           ruT5-Base       0.26      0.69      0.37       440
# ruT5-Base-Multitask       0.26      0.04      0.07       370
#          ruT5-Large       0.10      0.17      0.13       290
#
#            accuracy                           0.37     12987
# ...

# %%
figure = plt.figure(figsize=(10, 4))
plt.hist([df['labels'], df['predictions']], label=['target', 'predictions'])
plt.xlabel('Classes')
plt.ylabel('The number of sentences')
plt.title('CNN')
plt.legend(loc='upper left')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## LSTM-word2vec

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/RuATD/LSTM_Word2Vec.csv')

# %%
confusion(df,'LSTM word2vec')

# %%
print('***RESULTS LSTM word2vec***')
print(classification_report(df['labels'], df['predictions']))
# Out:
# ***RESULTS LSTM word2vec***
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                      precision    recall  f1-score   support
#
#              M-BART       0.44      0.49      0.46       418
#            M-BART50       0.30      0.58      0.40      1986
#             M2M-100       0.24      0.16      0.19      1804
#             OPUS-MT       0.23      0.28      0.25      2014
# ...

# %%
figure = plt.figure(figsize=(10, 4))
plt.hist([df['labels'], df['predictions']], label=['target', 'predictions'])
plt.xlabel('Classes')
plt.ylabel('The number of sentences')
plt.title('LSTM word2vec')
plt.legend(loc='upper left')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## tf-idf

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/RuATD/tfidf.csv')

# %%
confusion(df,'tfidf')

# %%
print('***RESULTS tfidf***')
print(classification_report(df['labels'], df['predictions']))
# Out:
# ***RESULTS tfidf***
#                      precision    recall  f1-score   support
#
#              M-BART       0.52      0.40      0.45       418
#            M-BART50       0.30      0.39      0.34      1986
#             M2M-100       0.23      0.23      0.23      1804
#             OPUS-MT       0.26      0.34      0.29      2014
#           mT5-Large       0.17      0.12      0.14       810
#           mT5-Small       0.17      0.09      0.11       490
#        ruGPT2-Large       0.36      0.27      0.31       395
#        ruGPT3-Large       0.37      0.40      0.38      1645
#       ruGPT3-Medium       0.37      0.32      0.34      1170
#        ruGPT3-Small       0.38      0.31      0.34      1155
#           ruT5-Base       0.43      0.38      0.40       440
# ruT5-Base-Multitask       0.09      0.03      0.04       370
#          ruT5-Large       0.05      0.02      0.03       290
#
#            accuracy                           0.30     12987
# ...

# %%
figure = plt.figure(figsize=(10, 4))
plt.hist([df['labels'], df['predictions']], label=['target', 'predictions'])
plt.xlabel('Classes')
plt.ylabel('The number of sentences')
plt.title('TF-IDF')
plt.legend(loc='upper left')
plt.xticks(rotation=45)
plt.show()

# %%
figure = plt.figure(figsize=(10, 4))
plt.hist([df['labels'], df['predictions']], label=['target', 'predictions'])
plt.xlabel('Classes')
plt.ylabel('The number of sentences')
plt.title('TF-IDF')
plt.legend(loc='upper left')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Combo model only machine predictiond and labels

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/RuATD/combo_model-2.csv')

# %%
confusion(df, 'Combo model: only machine')

# %%
print('***RESULTS: Combo model only machine***')
print(classification_report(df['labels'], df['predictions']))
# Out:
# ***RESULTS: Combo model only machine***
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                      precision    recall  f1-score   support
#
#               Human       0.00      0.00      0.00      2472
#              M-BART       0.42      0.51      0.46       352
#            M-BART50       0.36      0.46      0.40      1856
#             M2M-100       0.23      0.23      0.23      1611
# ...

# %%
figure = plt.figure(figsize=(10, 4))
plt.hist([df['labels'], df['predictions']], label=['target', 'predictions'])
plt.xlabel('Classes')
plt.ylabel('The number of sentences')
plt.title('Combo model: only machine')
plt.legend(loc='upper left')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## combo model: with human labels

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/RuATD/combo_model.csv')

# %%
confusion(df,'combo')

# %%
print('***RESULTS combo***')
print(classification_report(df['labels'], df['predictions']))
# Out:
# ***RESULTS combo***
#                      precision    recall  f1-score   support
#
#              M-BART       0.52      0.36      0.42       418
#            M-BART50       0.41      0.48      0.44      1986
#             M2M-100       0.29      0.29      0.29      1804
#             OPUS-MT       0.33      0.41      0.36      2014
#           mT5-Large       0.25      0.25      0.25       810
#           mT5-Small       0.29      0.22      0.25       490
#        ruGPT2-Large       0.64      0.50      0.56       395
#        ruGPT3-Large       0.48      0.60      0.53      1645
#       ruGPT3-Medium       0.45      0.10      0.16      1170
#        ruGPT3-Small       0.46      0.59      0.52      1155
#           ruT5-Base       0.54      0.72      0.61       440
# ruT5-Base-Multitask       0.38      0.02      0.05       370
#          ruT5-Large       0.15      0.06      0.08       290
#
#            accuracy                           0.39     12987
# ...

# %%
figure = plt.figure(figsize=(10, 4))
plt.hist([df['labels'], df['predictions']], label=['target', 'predictions'])
plt.xlabel('Classes')
plt.ylabel('The number of sentences')
plt.title('Combo model')
plt.legend(loc='upper left')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Combo model: with human labels and predictions

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/RuATD/final_results.csv')

# %%
confusion(df,'Combo model with human')

# %%
print('***RESULTS Combo model with human***')
print(classification_report(df['labels'], df['predictions']))
# Out:
# ***RESULTS Combo model with human***
#                      precision    recall  f1-score   support
#
#               Human       0.80      0.71      0.75      8524
#              M-BART       0.42      0.43      0.42       418
#            M-BART50       0.36      0.43      0.39      1986
#             M2M-100       0.23      0.21      0.22      1804
#             OPUS-MT       0.28      0.45      0.34      2014
#           mT5-Large       0.12      0.11      0.12       810
#           mT5-Small       0.20      0.24      0.22       490
#        ruGPT2-Large       0.57      0.48      0.52       395
#        ruGPT3-Large       0.44      0.52      0.48      1645
#       ruGPT3-Medium       0.48      0.22      0.30      1170
#        ruGPT3-Small       0.44      0.50      0.47      1155
#           ruT5-Base       0.43      0.57      0.49       440
# ruT5-Base-Multitask       0.28      0.02      0.04       370
#          ruT5-Large       0.06      0.03      0.04       290
#
# ...

# %%
figure = plt.figure(figsize=(10, 4))
plt.hist([df['labels'], df['predictions']], label=['target', 'predictions'])
plt.xlabel('Classes')
plt.ylabel('The number of sentences')
plt.title('Combo model with human')
plt.legend(loc='upper left')
plt.xticks(rotation=45)
plt.show()
