# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.17.0-py3-none-any.whl (3.8 MB)
#      |████████████████████████████████| 3.8 MB 14.0 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Collecting sacremoses
#   Downloading sacremoses-0.0.49-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 48.1 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.11.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.5)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.4.0-py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 7.1 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 59.1 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.63.0)
# Collecting tokenizers!=0.11.3,>=0.11.1
#   Downloading tokenizers-0.11.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.5 MB)
#      |████████████████████████████████| 6.5 MB 55.0 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.7.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.4.0 pyyaml-6.0 sacremoses-0.0.49 tokenizers-0.11.6 transformers-4.17.0

# %%
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from transformers import AdamW
from transformers import get_linear_schedule_with_warmup

class CustomDataset(Dataset):

  def __init__(self, texts, targets, tokenizer, max_len=512):
    self.texts = texts
    self.targets = targets
    self.tokenizer = tokenizer
    self.max_len = max_len

  def __len__(self):
    return len(self.texts)

  def __getitem__(self, idx):
    text = str(self.texts[idx])
    target = self.targets[idx]

    encoding = self.tokenizer.encode_plus(
        text,
        add_special_tokens=True,
        max_length=self.max_len,
        return_token_type_ids=False,
        padding='max_length',
        truncation=True,
        return_attention_mask=True,
        return_tensors='pt',
    )

    return {
      'text': text,
      'input_ids': encoding['input_ids'].flatten(),
      'attention_mask': encoding['attention_mask'].flatten(),
      'targets': torch.tensor(target, dtype=torch.long)
    }

# %%
from transformers import BertTokenizer, BertForSequenceClassification
model_path = 'cointegrated/rubert-tiny'
model = BertForSequenceClassification.from_pretrained(model_path)
tokenizer = BertTokenizer.from_pretrained(model_path)
# Out:
# Downloading:   0%|          | 0.00/632 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/45.5M [00:00<?, ?B/s]
# Some weights of the model checkpoint at cointegrated/rubert-tiny were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at cointegrated/rubert-tiny and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Downloading:   0%|          | 0.00/235k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/341 [00:00<?, ?B/s]

# %%
optimizer = AdamW(model.parameters(),
                  lr = 2e-5, # args.learning_rate - default is 5e-5, our notebook had 2e-5
                  eps = 1e-8 # args.adam_epsilon  - default is 1e-8.
                )
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,

# %%
import pandas as pd

train = pd.read_csv('/content/gdrive/MyDrive/data/train.csv')
val = pd.read_csv('/content/gdrive/MyDrive/data/val.csv')
test = pd.read_csv('/content/gdrive/MyDrive/data/test.csv')

train['Class_bi'] = train['Class'].apply(lambda x: 1 if x=='Human' else 0)
val['Class_bi'] = val['Class'].apply(lambda x: 1 if x=='Human' else 0)

# %%
train_set = CustomDataset(train['Text'], train['Class_bi'], tokenizer)
valid_set = CustomDataset(val['Text'], val['Class_bi'], tokenizer)

        # create data loaders
train_loader = DataLoader(train_set, batch_size=16, shuffle=True)
valid_loader = DataLoader(valid_set, batch_size=16, shuffle=True)

# %%
from transformers import get_linear_schedule_with_warmup
epochs = 3

# Total number of training steps is [number of batches] x [number of epochs]. 
# (Note that this is not the same as the number of training samples).
total_steps = len(train_loader) * epochs

# Create the learning rate scheduler.
scheduler = get_linear_schedule_with_warmup(optimizer, 
                                            num_warmup_steps = 0, # Default value in run_glue.py
                                            num_training_steps = total_steps)

# %%
import numpy as np

# Function to calculate the accuracy of our predictions vs labels
def flat_accuracy(preds, labels):
    pred_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return np.sum(pred_flat == labels_flat) / len(labels_flat)

# %%
import time
import datetime

def format_time(elapsed):
    '''
    Takes a time in seconds and returns a string hh:mm:ss
    '''
    # Round to the nearest second.
    elapsed_rounded = int(round((elapsed)))
    
    # Format as hh:mm:ss
    return str(datetime.timedelta(seconds=elapsed_rounded))

# %%
import random
import numpy as np
import torch

device = 'cuda:0'
model.to(device)

# This training code is based on the `run_glue.py` script here:
# https://github.com/huggingface/transformers/blob/5bfcd0485ece086ebcbed2d008813037968a9e58/examples/run_glue.py#L128

# Set the seed value all over the place to make this reproducible.
seed_val = 42

random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

# We'll store a number of quantities such as training and validation loss, 
# validation accuracy, and timings.
training_stats = []

# Measure the total training time for the whole run.
total_t0 = time.time()

# For each epoch...
for epoch_i in range(0, epochs):
    
    # ========================================
    #               Training
    # ========================================
    
    # Perform one full pass over the training set.

    print("")
    print('======== Epoch {:} / {:} ========'.format(epoch_i + 1, epochs))
    print('Training...')

    # Measure how long the training epoch takes.
    t0 = time.time()

    # Reset the total loss for this epoch.
    total_train_loss = 0
    model.train()

    # For each batch of training data...
    for step, batch in enumerate(train_loader):

        # Progress update every 40 batches.
        if step % 40 == 0 and not step == 0:
            # Calculate elapsed time in minutes.
            elapsed = format_time(time.time() - t0)
            
            # Report progress.
            print('  Batch {:>5,}  of  {:>5,}.    Elapsed: {:}.'.format(step, len(train_loader), elapsed))

        b_input_ids = batch['input_ids'].to(device)
        b_input_mask = batch['attention_mask'].to(device)
        b_labels = batch['targets'].to(device)

        model.zero_grad()        
        output = model(b_input_ids, 
                             token_type_ids=None, 
                             attention_mask=b_input_mask, 
                             labels=b_labels)
        loss = output['loss']
        logits = output['logits']
        total_train_loss += loss.item()

        # Perform a backward pass to calculate the gradients.
        loss.backward()

        # Clip the norm of the gradients to 1.0.
        # This is to help prevent the "exploding gradients" problem.
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

        # Update parameters and take a step using the computed gradient.
        # The optimizer dictates the "update rule"--how the parameters are
        # modified based on their gradients, the learning rate, etc.
        optimizer.step()

        # Update the learning rate.
        scheduler.step()

    # Calculate the average loss over all of the batches.
    avg_train_loss = total_train_loss / len(train_loader)            
    
    # Measure how long this epoch took.
    training_time = format_time(time.time() - t0)

    print("")
    print("  Average training loss: {0:.2f}".format(avg_train_loss))
    print("  Training epcoh took: {:}".format(training_time))
        
    # ========================================
    #               Validation
    # ========================================
    # After the completion of each training epoch, measure our performance on
    # our validation set.

    print("")
    print("Running Validation...")

    t0 = time.time()

    # Put the model in evaluation mode--the dropout layers behave differently
    # during evaluation.
    model.eval()

    # Tracking variables 
    total_eval_accuracy = 0
    total_eval_loss = 0
    nb_eval_steps = 0

    # Evaluate data for one epoch
    for batch in valid_loader:
        
        # Unpack this training batch from our dataloader. 
        #
        # As we unpack the batch, we'll also copy each tensor to the GPU using 
        # the `to` method.
        #
        # `batch` contains three pytorch tensors:
        #   [0]: input ids 
        #   [1]: attention masks
        #   [2]: labels 
        b_input_ids = batch['input_ids'].to(device)
        b_input_mask = batch['attention_mask'].to(device)
        b_labels = batch['targets'].to(device)
        
        # Tell pytorch not to bother with constructing the compute graph during
        # the forward pass, since this is only needed for backprop (training).
        with torch.no_grad():        
            output = model(b_input_ids, 
                                   token_type_ids=None, 
                                   attention_mask=b_input_mask,
                                   labels=b_labels)
            loss = output['loss']
            logits = output['logits']
            
        # Accumulate the validation loss.
        total_eval_loss += loss.item()

        # Move logits and labels to CPU
        logits = logits.detach().cpu().numpy()
        label_ids = b_labels.to('cpu').numpy()

        # Calculate the accuracy for this batch of test sentences, and
        # accumulate it over all batches.
        total_eval_accuracy += flat_accuracy(logits, label_ids)
        

    # Report the final accuracy for this validation run.
    avg_val_accuracy = total_eval_accuracy / len(valid_loader)
    print("  Accuracy: {0:.2f}".format(avg_val_accuracy))

    # Calculate the average loss over all of the batches.
    avg_val_loss = total_eval_loss / len(valid_loader)
    
    # Measure how long the validation run took.
    validation_time = format_time(time.time() - t0)
    
    print("  Validation Loss: {0:.2f}".format(avg_val_loss))
    print("  Validation took: {:}".format(validation_time))

    # Record all statistics from this epoch.
    training_stats.append(
        {
            'epoch': epoch_i + 1,
            'Training Loss': avg_train_loss,
            'Valid. Loss': avg_val_loss,
            'Valid. Accur.': avg_val_accuracy,
            'Training Time': training_time,
            'Validation Time': validation_time
        }
    )

print("")
print("Training complete!")

print("Total training took {:} (h:mm:ss)".format(format_time(time.time()-total_t0)))
# Out:
# ======== Epoch 1 / 3 ========
# Training...
#   Batch    40  of  8,067.    Elapsed: 0:00:07.
#   Batch    80  of  8,067.    Elapsed: 0:00:13.
#   Batch   120  of  8,067.    Elapsed: 0:00:19.
#   Batch   160  of  8,067.    Elapsed: 0:00:24.
#   Batch   200  of  8,067.    Elapsed: 0:00:30.
#   Batch   240  of  8,067.    Elapsed: 0:00:35.
#   Batch   280  of  8,067.    Elapsed: 0:00:41.
#   Batch   320  of  8,067.    Elapsed: 0:00:47.
#   Batch   360  of  8,067.    Elapsed: 0:00:52.
#   Batch   400  of  8,067.    Elapsed: 0:00:58.
#   Batch   440  of  8,067.    Elapsed: 0:01:03.
#   Batch   480  of  8,067.    Elapsed: 0:01:09.
#   Batch   520  of  8,067.    Elapsed: 0:01:15.
#   Batch   560  of  8,067.    Elapsed: 0:01:21.
#   Batch   600  of  8,067.    Elapsed: 0:01:26.
#   Batch   640  of  8,067.    Elapsed: 0:01:32.
#   Batch   680  of  8,067.    Elapsed: 0:01:38.
#   Batch   720  of  8,067.    Elapsed: 0:01:43.
#   Batch   760  of  8,067.    Elapsed: 0:01:49.
#   Batch   800  of  8,067.    Elapsed: 0:01:55.
#   Batch   840  of  8,067.    Elapsed: 0:02:01.
#   Batch   880  of  8,067.    Elapsed: 0:02:06.
#   Batch   920  of  8,067.    Elapsed: 0:02:12.
#   Batch   960  of  8,067.    Elapsed: 0:02:18.
#   Batch 1,000  of  8,067.    Elapsed: 0:02:23.
#   Batch 1,040  of  8,067.    Elapsed: 0:02:29.
#   Batch 1,080  of  8,067.    Elapsed: 0:02:35.
#   Batch 1,120  of  8,067.    Elapsed: 0:02:41.
#   Batch 1,160  of  8,067.    Elapsed: 0:02:46.
#   Batch 1,200  of  8,067.    Elapsed: 0:02:52.
#   Batch 1,240  of  8,067.    Elapsed: 0:02:58.
#   Batch 1,280  of  8,067.    Elapsed: 0:03:03.
#   Batch 1,320  of  8,067.    Elapsed: 0:03:09.
#   Batch 1,360  of  8,067.    Elapsed: 0:03:15.
#   Batch 1,400  of  8,067.    Elapsed: 0:03:21.
#   Batch 1,440  of  8,067.    Elapsed: 0:03:27.
#   Batch 1,480  of  8,067.    Elapsed: 0:03:32.
#   Batch 1,520  of  8,067.    Elapsed: 0:03:38.
#   Batch 1,560  of  8,067.    Elapsed: 0:03:44.
#   Batch 1,600  of  8,067.    Elapsed: 0:03:50.
#   Batch 1,640  of  8,067.    Elapsed: 0:03:56.
#   Batch 1,680  of  8,067.    Elapsed: 0:04:01.
#   Batch 1,720  of  8,067.    Elapsed: 0:04:07.
#   Batch 1,760  of  8,067.    Elapsed: 0:04:13.
#   Batch 1,800  of  8,067.    Elapsed: 0:04:19.
#   Batch 1,840  of  8,067.    Elapsed: 0:04:25.
#   Batch 1,880  of  8,067.    Elapsed: 0:04:31.
#   Batch 1,920  of  8,067.    Elapsed: 0:04:36.
#   Batch 1,960  of  8,067.    Elapsed: 0:04:42.
#   Batch 2,000  of  8,067.    Elapsed: 0:04:48.
#   Batch 2,040  of  8,067.    Elapsed: 0:04:54.
#   Batch 2,080  of  8,067.    Elapsed: 0:05:00.
#   Batch 2,120  of  8,067.    Elapsed: 0:05:05.
#   Batch 2,160  of  8,067.    Elapsed: 0:05:11.
#   Batch 2,200  of  8,067.    Elapsed: 0:05:17.
#   Batch 2,240  of  8,067.    Elapsed: 0:05:23.
#   Batch 2,280  of  8,067.    Elapsed: 0:05:29.
#   Batch 2,320  of  8,067.    Elapsed: 0:05:35.
#   Batch 2,360  of  8,067.    Elapsed: 0:05:40.
#   Batch 2,400  of  8,067.    Elapsed: 0:05:46.
#   Batch 2,440  of  8,067.    Elapsed: 0:05:52.
#   Batch 2,480  of  8,067.    Elapsed: 0:05:58.
#   Batch 2,520  of  8,067.    Elapsed: 0:06:04.
#   Batch 2,560  of  8,067.    Elapsed: 0:06:09.
#   Batch 2,600  of  8,067.    Elapsed: 0:06:15.
#   Batch 2,640  of  8,067.    Elapsed: 0:06:21.
#   Batch 2,680  of  8,067.    Elapsed: 0:06:27.
#   Batch 2,720  of  8,067.    Elapsed: 0:06:33.
#   Batch 2,760  of  8,067.    Elapsed: 0:06:39.
#   Batch 2,800  of  8,067.    Elapsed: 0:06:45.
#   Batch 2,840  of  8,067.    Elapsed: 0:06:50.
#   Batch 2,880  of  8,067.    Elapsed: 0:06:56.
#   Batch 2,920  of  8,067.    Elapsed: 0:07:02.
#   Batch 2,960  of  8,067.    Elapsed: 0:07:08.
#   Batch 3,000  of  8,067.    Elapsed: 0:07:14.
#   Batch 3,040  of  8,067.    Elapsed: 0:07:20.
#   Batch 3,080  of  8,067.    Elapsed: 0:07:26.
#   Batch 3,120  of  8,067.    Elapsed: 0:07:31.
#   Batch 3,160  of  8,067.    Elapsed: 0:07:37.
#   Batch 3,200  of  8,067.    Elapsed: 0:07:43.
#   Batch 3,240  of  8,067.    Elapsed: 0:07:49.
#   Batch 3,280  of  8,067.    Elapsed: 0:07:55.
#   Batch 3,320  of  8,067.    Elapsed: 0:08:00.
#   Batch 3,360  of  8,067.    Elapsed: 0:08:06.
#   Batch 3,400  of  8,067.    Elapsed: 0:08:12.
#   Batch 3,440  of  8,067.    Elapsed: 0:08:18.
#   Batch 3,480  of  8,067.    Elapsed: 0:08:24.
#   Batch 3,520  of  8,067.    Elapsed: 0:08:30.
#   Batch 3,560  of  8,067.    Elapsed: 0:08:36.
#   Batch 3,600  of  8,067.    Elapsed: 0:08:42.
#   Batch 3,640  of  8,067.    Elapsed: 0:08:47.
#   Batch 3,680  of  8,067.    Elapsed: 0:08:53.
#   Batch 3,720  of  8,067.    Elapsed: 0:08:59.
#   Batch 3,760  of  8,067.    Elapsed: 0:09:05.
#   Batch 3,800  of  8,067.    Elapsed: 0:09:11.
#   Batch 3,840  of  8,067.    Elapsed: 0:09:17.
#   Batch 3,880  of  8,067.    Elapsed: 0:09:23.
#   Batch 3,920  of  8,067.    Elapsed: 0:09:28.
#   Batch 3,960  of  8,067.    Elapsed: 0:09:34.
#   Batch 4,000  of  8,067.    Elapsed: 0:09:40.
#   Batch 4,040  of  8,067.    Elapsed: 0:09:46.
#   Batch 4,080  of  8,067.    Elapsed: 0:09:52.
#   Batch 4,120  of  8,067.    Elapsed: 0:09:58.
#   Batch 4,160  of  8,067.    Elapsed: 0:10:03.
#   Batch 4,200  of  8,067.    Elapsed: 0:10:09.
#   Batch 4,240  of  8,067.    Elapsed: 0:10:15.
#   Batch 4,280  of  8,067.    Elapsed: 0:10:21.
#   Batch 4,320  of  8,067.    Elapsed: 0:10:27.
#   Batch 4,360  of  8,067.    Elapsed: 0:10:33.
#   Batch 4,400  of  8,067.    Elapsed: 0:10:39.
#   Batch 4,440  of  8,067.    Elapsed: 0:10:44.
#   Batch 4,480  of  8,067.    Elapsed: 0:10:50.
#   Batch 4,520  of  8,067.    Elapsed: 0:10:56.
#   Batch 4,560  of  8,067.    Elapsed: 0:11:02.
#   Batch 4,600  of  8,067.    Elapsed: 0:11:08.
#   Batch 4,640  of  8,067.    Elapsed: 0:11:14.
#   Batch 4,680  of  8,067.    Elapsed: 0:11:19.
#   Batch 4,720  of  8,067.    Elapsed: 0:11:25.
#   Batch 4,760  of  8,067.    Elapsed: 0:11:31.
#   Batch 4,800  of  8,067.    Elapsed: 0:11:37.
#   Batch 4,840  of  8,067.    Elapsed: 0:11:43.
#   Batch 4,880  of  8,067.    Elapsed: 0:11:49.
#   Batch 4,920  of  8,067.    Elapsed: 0:11:54.
#   Batch 4,960  of  8,067.    Elapsed: 0:12:00.
#   Batch 5,000  of  8,067.    Elapsed: 0:12:06.
#   Batch 5,040  of  8,067.    Elapsed: 0:12:12.
#   Batch 5,080  of  8,067.    Elapsed: 0:12:18.
#   Batch 5,120  of  8,067.    Elapsed: 0:12:24.
#   Batch 5,160  of  8,067.    Elapsed: 0:12:30.
#   Batch 5,200  of  8,067.    Elapsed: 0:12:35.
#   Batch 5,240  of  8,067.    Elapsed: 0:12:41.
#   Batch 5,280  of  8,067.    Elapsed: 0:12:47.
#   Batch 5,320  of  8,067.    Elapsed: 0:12:53.
#   Batch 5,360  of  8,067.    Elapsed: 0:12:59.
#   Batch 5,400  of  8,067.    Elapsed: 0:13:05.
#   Batch 5,440  of  8,067.    Elapsed: 0:13:11.
#   Batch 5,480  of  8,067.    Elapsed: 0:13:17.
#   Batch 5,520  of  8,067.    Elapsed: 0:13:22.
#   Batch 5,560  of  8,067.    Elapsed: 0:13:28.
#   Batch 5,600  of  8,067.    Elapsed: 0:13:34.
#   Batch 5,640  of  8,067.    Elapsed: 0:13:40.
#   Batch 5,680  of  8,067.    Elapsed: 0:13:46.
#   Batch 5,720  of  8,067.    Elapsed: 0:13:52.
#   Batch 5,760  of  8,067.    Elapsed: 0:13:57.
#   Batch 5,800  of  8,067.    Elapsed: 0:14:03.
#   Batch 5,840  of  8,067.    Elapsed: 0:14:09.
#   Batch 5,880  of  8,067.    Elapsed: 0:14:15.
#   Batch 5,920  of  8,067.    Elapsed: 0:14:21.
#   Batch 5,960  of  8,067.    Elapsed: 0:14:27.
#   Batch 6,000  of  8,067.    Elapsed: 0:14:33.
#   Batch 6,040  of  8,067.    Elapsed: 0:14:38.
#   Batch 6,080  of  8,067.    Elapsed: 0:14:44.
#   Batch 6,120  of  8,067.    Elapsed: 0:14:50.
#   Batch 6,160  of  8,067.    Elapsed: 0:14:56.
#   Batch 6,200  of  8,067.    Elapsed: 0:15:02.
#   Batch 6,240  of  8,067.    Elapsed: 0:15:08.
#   Batch 6,280  of  8,067.    Elapsed: 0:15:14.
#   Batch 6,320  of  8,067.    Elapsed: 0:15:20.
#   Batch 6,360  of  8,067.    Elapsed: 0:15:26.
#   Batch 6,400  of  8,067.    Elapsed: 0:15:31.
#   Batch 6,440  of  8,067.    Elapsed: 0:15:37.
#   Batch 6,480  of  8,067.    Elapsed: 0:15:43.
#   Batch 6,520  of  8,067.    Elapsed: 0:15:49.
#   Batch 6,560  of  8,067.    Elapsed: 0:15:55.
#   Batch 6,600  of  8,067.    Elapsed: 0:16:00.
#   Batch 6,640  of  8,067.    Elapsed: 0:16:06.
#   Batch 6,680  of  8,067.    Elapsed: 0:16:12.
#   Batch 6,720  of  8,067.    Elapsed: 0:16:18.
#   Batch 6,760  of  8,067.    Elapsed: 0:16:24.
#   Batch 6,800  of  8,067.    Elapsed: 0:16:30.
#   Batch 6,840  of  8,067.    Elapsed: 0:16:36.
#   Batch 6,880  of  8,067.    Elapsed: 0:16:42.
#   Batch 6,920  of  8,067.    Elapsed: 0:16:47.
#   Batch 6,960  of  8,067.    Elapsed: 0:16:53.
#   Batch 7,000  of  8,067.    Elapsed: 0:16:59.
#   Batch 7,040  of  8,067.    Elapsed: 0:17:05.
#   Batch 7,080  of  8,067.    Elapsed: 0:17:11.
#   Batch 7,120  of  8,067.    Elapsed: 0:17:17.
#   Batch 7,160  of  8,067.    Elapsed: 0:17:22.
#   Batch 7,200  of  8,067.    Elapsed: 0:17:28.
#   Batch 7,240  of  8,067.    Elapsed: 0:17:34.
#   Batch 7,280  of  8,067.    Elapsed: 0:17:40.
#   Batch 7,320  of  8,067.    Elapsed: 0:17:46.
#   Batch 7,360  of  8,067.    Elapsed: 0:17:52.
#   Batch 7,400  of  8,067.    Elapsed: 0:17:57.
#   Batch 7,440  of  8,067.    Elapsed: 0:18:03.
#   Batch 7,480  of  8,067.    Elapsed: 0:18:09.
#   Batch 7,520  of  8,067.    Elapsed: 0:18:15.
#   Batch 7,560  of  8,067.    Elapsed: 0:18:21.
#   Batch 7,600  of  8,067.    Elapsed: 0:18:27.
#   Batch 7,640  of  8,067.    Elapsed: 0:18:32.
#   Batch 7,680  of  8,067.    Elapsed: 0:18:38.
#   Batch 7,720  of  8,067.    Elapsed: 0:18:44.
#   Batch 7,760  of  8,067.    Elapsed: 0:18:50.
#   Batch 7,800  of  8,067.    Elapsed: 0:18:56.
#   Batch 7,840  of  8,067.    Elapsed: 0:19:02.
#   Batch 7,880  of  8,067.    Elapsed: 0:19:07.
#   Batch 7,920  of  8,067.    Elapsed: 0:19:13.
#   Batch 7,960  of  8,067.    Elapsed: 0:19:19.
#   Batch 8,000  of  8,067.    Elapsed: 0:19:25.
#   Batch 8,040  of  8,067.    Elapsed: 0:19:31.
#
#   Average training loss: 0.46
#   Training epcoh took: 0:19:35
#
# Running Validation...
#   Accuracy: 0.80
#   Validation Loss: 0.41
#   Validation took: 0:01:22
#
# ======== Epoch 2 / 3 ========
# Training...
#   Batch    40  of  8,067.    Elapsed: 0:00:06.
#   Batch    80  of  8,067.    Elapsed: 0:00:12.
#   Batch   120  of  8,067.    Elapsed: 0:00:18.
#   Batch   160  of  8,067.    Elapsed: 0:00:23.
#   Batch   200  of  8,067.    Elapsed: 0:00:29.
#   Batch   240  of  8,067.    Elapsed: 0:00:35.
#   Batch   280  of  8,067.    Elapsed: 0:00:41.
#   Batch   320  of  8,067.    Elapsed: 0:00:47.
#   Batch   360  of  8,067.    Elapsed: 0:00:53.
#   Batch   400  of  8,067.    Elapsed: 0:00:59.
#   Batch   440  of  8,067.    Elapsed: 0:01:04.
#   Batch   480  of  8,067.    Elapsed: 0:01:10.
#   Batch   520  of  8,067.    Elapsed: 0:01:16.
#   Batch   560  of  8,067.    Elapsed: 0:01:22.
#   Batch   600  of  8,067.    Elapsed: 0:01:28.
#   Batch   640  of  8,067.    Elapsed: 0:01:34.
#   Batch   680  of  8,067.    Elapsed: 0:01:39.
#   Batch   720  of  8,067.    Elapsed: 0:01:45.
#   Batch   760  of  8,067.    Elapsed: 0:01:51.
#   Batch   800  of  8,067.    Elapsed: 0:01:57.
#   Batch   840  of  8,067.    Elapsed: 0:02:03.
#   Batch   880  of  8,067.    Elapsed: 0:02:08.
#   Batch   920  of  8,067.    Elapsed: 0:02:14.
#   Batch   960  of  8,067.    Elapsed: 0:02:20.
#   Batch 1,000  of  8,067.    Elapsed: 0:02:26.
#   Batch 1,040  of  8,067.    Elapsed: 0:02:32.
#   Batch 1,080  of  8,067.    Elapsed: 0:02:38.
#   Batch 1,120  of  8,067.    Elapsed: 0:02:44.
#   Batch 1,160  of  8,067.    Elapsed: 0:02:49.
#   Batch 1,200  of  8,067.    Elapsed: 0:02:55.
#   Batch 1,240  of  8,067.    Elapsed: 0:03:01.
#   Batch 1,280  of  8,067.    Elapsed: 0:03:07.
#   Batch 1,320  of  8,067.    Elapsed: 0:03:13.
#   Batch 1,360  of  8,067.    Elapsed: 0:03:18.
#   Batch 1,400  of  8,067.    Elapsed: 0:03:24.
#   Batch 1,440  of  8,067.    Elapsed: 0:03:30.
#   Batch 1,480  of  8,067.    Elapsed: 0:03:36.
#   Batch 1,520  of  8,067.    Elapsed: 0:03:42.
#   Batch 1,560  of  8,067.    Elapsed: 0:03:47.
#   Batch 1,600  of  8,067.    Elapsed: 0:03:53.
#   Batch 1,640  of  8,067.    Elapsed: 0:03:59.
#   Batch 1,680  of  8,067.    Elapsed: 0:04:05.
#   Batch 1,720  of  8,067.    Elapsed: 0:04:11.
#   Batch 1,760  of  8,067.    Elapsed: 0:04:17.
#   Batch 1,800  of  8,067.    Elapsed: 0:04:23.
#   Batch 1,840  of  8,067.    Elapsed: 0:04:29.
#   Batch 1,880  of  8,067.    Elapsed: 0:04:34.
#   Batch 1,920  of  8,067.    Elapsed: 0:04:40.
#   Batch 1,960  of  8,067.    Elapsed: 0:04:46.
#   Batch 2,000  of  8,067.    Elapsed: 0:04:52.
#   Batch 2,040  of  8,067.    Elapsed: 0:04:58.
#   Batch 2,080  of  8,067.    Elapsed: 0:05:04.
#   Batch 2,120  of  8,067.    Elapsed: 0:05:10.
#   Batch 2,160  of  8,067.    Elapsed: 0:05:16.
#   Batch 2,200  of  8,067.    Elapsed: 0:05:22.
#   Batch 2,240  of  8,067.    Elapsed: 0:05:27.
#   Batch 2,280  of  8,067.    Elapsed: 0:05:33.
#   Batch 2,320  of  8,067.    Elapsed: 0:05:39.
#   Batch 2,360  of  8,067.    Elapsed: 0:05:45.
#   Batch 2,400  of  8,067.    Elapsed: 0:05:51.
#   Batch 2,440  of  8,067.    Elapsed: 0:05:57.
#   Batch 2,480  of  8,067.    Elapsed: 0:06:02.
#   Batch 2,520  of  8,067.    Elapsed: 0:06:08.
#   Batch 2,560  of  8,067.    Elapsed: 0:06:14.
#   Batch 2,600  of  8,067.    Elapsed: 0:06:20.
#   Batch 2,640  of  8,067.    Elapsed: 0:06:26.
#   Batch 2,680  of  8,067.    Elapsed: 0:06:32.
#   Batch 2,720  of  8,067.    Elapsed: 0:06:38.
#   Batch 2,760  of  8,067.    Elapsed: 0:06:43.
#   Batch 2,800  of  8,067.    Elapsed: 0:06:49.
#   Batch 2,840  of  8,067.    Elapsed: 0:06:55.
#   Batch 2,880  of  8,067.    Elapsed: 0:07:01.
#   Batch 2,920  of  8,067.    Elapsed: 0:07:07.
#   Batch 2,960  of  8,067.    Elapsed: 0:07:13.
#   Batch 3,000  of  8,067.    Elapsed: 0:07:18.
#   Batch 3,040  of  8,067.    Elapsed: 0:07:24.
#   Batch 3,080  of  8,067.    Elapsed: 0:07:30.
#   Batch 3,120  of  8,067.    Elapsed: 0:07:36.
#   Batch 3,160  of  8,067.    Elapsed: 0:07:42.
#   Batch 3,200  of  8,067.    Elapsed: 0:07:48.
#   Batch 3,240  of  8,067.    Elapsed: 0:07:54.
#   Batch 3,280  of  8,067.    Elapsed: 0:08:00.
#   Batch 3,320  of  8,067.    Elapsed: 0:08:06.
#   Batch 3,360  of  8,067.    Elapsed: 0:08:11.
#   Batch 3,400  of  8,067.    Elapsed: 0:08:17.
#   Batch 3,440  of  8,067.    Elapsed: 0:08:23.
#   Batch 3,480  of  8,067.    Elapsed: 0:08:29.
#   Batch 3,520  of  8,067.    Elapsed: 0:08:35.
#   Batch 3,560  of  8,067.    Elapsed: 0:08:41.
#   Batch 3,600  of  8,067.    Elapsed: 0:08:46.
#   Batch 3,640  of  8,067.    Elapsed: 0:08:52.
#   Batch 3,680  of  8,067.    Elapsed: 0:08:58.
#   Batch 3,720  of  8,067.    Elapsed: 0:09:04.
#   Batch 3,760  of  8,067.    Elapsed: 0:09:10.
#   Batch 3,800  of  8,067.    Elapsed: 0:09:15.
#   Batch 3,840  of  8,067.    Elapsed: 0:09:21.
#   Batch 3,880  of  8,067.    Elapsed: 0:09:27.
#   Batch 3,920  of  8,067.    Elapsed: 0:09:33.
#   Batch 3,960  of  8,067.    Elapsed: 0:09:39.
#   Batch 4,000  of  8,067.    Elapsed: 0:09:45.
#   Batch 4,040  of  8,067.    Elapsed: 0:09:51.
#   Batch 4,080  of  8,067.    Elapsed: 0:09:56.
#   Batch 4,120  of  8,067.    Elapsed: 0:10:02.
#   Batch 4,160  of  8,067.    Elapsed: 0:10:08.
#   Batch 4,200  of  8,067.    Elapsed: 0:10:14.
#   Batch 4,240  of  8,067.    Elapsed: 0:10:20.
#   Batch 4,280  of  8,067.    Elapsed: 0:10:26.
#   Batch 4,320  of  8,067.    Elapsed: 0:10:32.
#   Batch 4,360  of  8,067.    Elapsed: 0:10:38.
#   Batch 4,400  of  8,067.    Elapsed: 0:10:43.
#   Batch 4,440  of  8,067.    Elapsed: 0:10:49.
#   Batch 4,480  of  8,067.    Elapsed: 0:10:55.
#   Batch 4,520  of  8,067.    Elapsed: 0:11:01.
#   Batch 4,560  of  8,067.    Elapsed: 0:11:07.
#   Batch 4,600  of  8,067.    Elapsed: 0:11:13.
#   Batch 4,640  of  8,067.    Elapsed: 0:11:19.
#   Batch 4,680  of  8,067.    Elapsed: 0:11:25.
#   Batch 4,720  of  8,067.    Elapsed: 0:11:30.
#   Batch 4,760  of  8,067.    Elapsed: 0:11:36.
#   Batch 4,800  of  8,067.    Elapsed: 0:11:42.
#   Batch 4,840  of  8,067.    Elapsed: 0:11:48.
#   Batch 4,880  of  8,067.    Elapsed: 0:11:54.
#   Batch 4,920  of  8,067.    Elapsed: 0:12:00.
#   Batch 4,960  of  8,067.    Elapsed: 0:12:06.
#   Batch 5,000  of  8,067.    Elapsed: 0:12:11.
#   Batch 5,040  of  8,067.    Elapsed: 0:12:17.
#   Batch 5,080  of  8,067.    Elapsed: 0:12:23.
#   Batch 5,120  of  8,067.    Elapsed: 0:12:29.
#   Batch 5,160  of  8,067.    Elapsed: 0:12:35.
#   Batch 5,200  of  8,067.    Elapsed: 0:12:41.
#   Batch 5,240  of  8,067.    Elapsed: 0:12:47.
#   Batch 5,280  of  8,067.    Elapsed: 0:12:52.
#   Batch 5,320  of  8,067.    Elapsed: 0:12:58.
#   Batch 5,360  of  8,067.    Elapsed: 0:13:04.
#   Batch 5,400  of  8,067.    Elapsed: 0:13:10.
#   Batch 5,440  of  8,067.    Elapsed: 0:13:16.
#   Batch 5,480  of  8,067.    Elapsed: 0:13:22.
#   Batch 5,520  of  8,067.    Elapsed: 0:13:28.
#   Batch 5,560  of  8,067.    Elapsed: 0:13:34.
#   Batch 5,600  of  8,067.    Elapsed: 0:13:39.
#   Batch 5,640  of  8,067.    Elapsed: 0:13:45.
#   Batch 5,680  of  8,067.    Elapsed: 0:13:51.
#   Batch 5,720  of  8,067.    Elapsed: 0:13:57.
#   Batch 5,760  of  8,067.    Elapsed: 0:14:03.
#   Batch 5,800  of  8,067.    Elapsed: 0:14:09.
#   Batch 5,840  of  8,067.    Elapsed: 0:14:15.
#   Batch 5,880  of  8,067.    Elapsed: 0:14:21.
#   Batch 5,920  of  8,067.    Elapsed: 0:14:26.
#   Batch 5,960  of  8,067.    Elapsed: 0:14:32.
#   Batch 6,000  of  8,067.    Elapsed: 0:14:38.
#   Batch 6,040  of  8,067.    Elapsed: 0:14:44.
#   Batch 6,080  of  8,067.    Elapsed: 0:14:50.
#   Batch 6,120  of  8,067.    Elapsed: 0:14:56.
#   Batch 6,160  of  8,067.    Elapsed: 0:15:02.
#   Batch 6,200  of  8,067.    Elapsed: 0:15:08.
#   Batch 6,240  of  8,067.    Elapsed: 0:15:13.
#   Batch 6,280  of  8,067.    Elapsed: 0:15:19.
#   Batch 6,320  of  8,067.    Elapsed: 0:15:25.
#   Batch 6,360  of  8,067.    Elapsed: 0:15:31.
#   Batch 6,400  of  8,067.    Elapsed: 0:15:37.
#   Batch 6,440  of  8,067.    Elapsed: 0:15:43.
#   Batch 6,480  of  8,067.    Elapsed: 0:15:48.
#   Batch 6,520  of  8,067.    Elapsed: 0:15:54.
#   Batch 6,560  of  8,067.    Elapsed: 0:16:00.
#   Batch 6,600  of  8,067.    Elapsed: 0:16:06.
#   Batch 6,640  of  8,067.    Elapsed: 0:16:12.
#   Batch 6,680  of  8,067.    Elapsed: 0:16:18.
#   Batch 6,720  of  8,067.    Elapsed: 0:16:24.
#   Batch 6,760  of  8,067.    Elapsed: 0:16:29.
#   Batch 6,800  of  8,067.    Elapsed: 0:16:35.
#   Batch 6,840  of  8,067.    Elapsed: 0:16:41.
#   Batch 6,880  of  8,067.    Elapsed: 0:16:47.
#   Batch 6,920  of  8,067.    Elapsed: 0:16:53.
#   Batch 6,960  of  8,067.    Elapsed: 0:16:59.
#   Batch 7,000  of  8,067.    Elapsed: 0:17:05.
#   Batch 7,040  of  8,067.    Elapsed: 0:17:10.
#   Batch 7,080  of  8,067.    Elapsed: 0:17:16.
#   Batch 7,120  of  8,067.    Elapsed: 0:17:22.
#   Batch 7,160  of  8,067.    Elapsed: 0:17:28.
#   Batch 7,200  of  8,067.    Elapsed: 0:17:34.
#   Batch 7,240  of  8,067.    Elapsed: 0:17:40.
#   Batch 7,280  of  8,067.    Elapsed: 0:17:45.
#   Batch 7,320  of  8,067.    Elapsed: 0:17:51.
#   Batch 7,360  of  8,067.    Elapsed: 0:17:57.
#   Batch 7,400  of  8,067.    Elapsed: 0:18:03.
#   Batch 7,440  of  8,067.    Elapsed: 0:18:09.
#   Batch 7,480  of  8,067.    Elapsed: 0:18:15.
#   Batch 7,520  of  8,067.    Elapsed: 0:18:21.
#   Batch 7,560  of  8,067.    Elapsed: 0:18:26.
#   Batch 7,600  of  8,067.    Elapsed: 0:18:32.
#   Batch 7,640  of  8,067.    Elapsed: 0:18:38.
#   Batch 7,680  of  8,067.    Elapsed: 0:18:44.
#   Batch 7,720  of  8,067.    Elapsed: 0:18:50.
#   Batch 7,760  of  8,067.    Elapsed: 0:18:56.
#   Batch 7,800  of  8,067.    Elapsed: 0:19:02.
#   Batch 7,840  of  8,067.    Elapsed: 0:19:08.
#   Batch 7,880  of  8,067.    Elapsed: 0:19:13.
#   Batch 7,920  of  8,067.    Elapsed: 0:19:19.
#   Batch 7,960  of  8,067.    Elapsed: 0:19:25.
#   Batch 8,000  of  8,067.    Elapsed: 0:19:31.
#   Batch 8,040  of  8,067.    Elapsed: 0:19:37.
#
#   Average training loss: 0.39
#   Training epcoh took: 0:19:41
#
# Running Validation...
#   Accuracy: 0.81
#   Validation Loss: 0.39
#   Validation took: 0:01:22
#
# ======== Epoch 3 / 3 ========
# Training...
#   Batch    40  of  8,067.    Elapsed: 0:00:06.
#   Batch    80  of  8,067.    Elapsed: 0:00:12.
#   Batch   120  of  8,067.    Elapsed: 0:00:18.
#   Batch   160  of  8,067.    Elapsed: 0:00:23.
#   Batch   200  of  8,067.    Elapsed: 0:00:29.
#   Batch   240  of  8,067.    Elapsed: 0:00:35.
#   Batch   280  of  8,067.    Elapsed: 0:00:41.
#   Batch   320  of  8,067.    Elapsed: 0:00:47.
#   Batch   360  of  8,067.    Elapsed: 0:00:53.
#   Batch   400  of  8,067.    Elapsed: 0:00:59.
#   Batch   440  of  8,067.    Elapsed: 0:01:05.
#   Batch   480  of  8,067.    Elapsed: 0:01:10.
#   Batch   520  of  8,067.    Elapsed: 0:01:16.
#   Batch   560  of  8,067.    Elapsed: 0:01:22.
#   Batch   600  of  8,067.    Elapsed: 0:01:28.
#   Batch   640  of  8,067.    Elapsed: 0:01:34.
#   Batch   680  of  8,067.    Elapsed: 0:01:40.
#   Batch   720  of  8,067.    Elapsed: 0:01:45.
#   Batch   760  of  8,067.    Elapsed: 0:01:51.
#   Batch   800  of  8,067.    Elapsed: 0:01:57.
#   Batch   840  of  8,067.    Elapsed: 0:02:03.
#   Batch   880  of  8,067.    Elapsed: 0:02:09.
#   Batch   920  of  8,067.    Elapsed: 0:02:15.
#   Batch   960  of  8,067.    Elapsed: 0:02:21.
#   Batch 1,000  of  8,067.    Elapsed: 0:02:26.
#   Batch 1,040  of  8,067.    Elapsed: 0:02:32.
#   Batch 1,080  of  8,067.    Elapsed: 0:02:38.
#   Batch 1,120  of  8,067.    Elapsed: 0:02:44.
#   Batch 1,160  of  8,067.    Elapsed: 0:02:50.
#   Batch 1,200  of  8,067.    Elapsed: 0:02:56.
#   Batch 1,240  of  8,067.    Elapsed: 0:03:02.
#   Batch 1,280  of  8,067.    Elapsed: 0:03:08.
#   Batch 1,320  of  8,067.    Elapsed: 0:03:13.
#   Batch 1,360  of  8,067.    Elapsed: 0:03:19.
#   Batch 1,400  of  8,067.    Elapsed: 0:03:25.
#   Batch 1,440  of  8,067.    Elapsed: 0:03:31.
#   Batch 1,480  of  8,067.    Elapsed: 0:03:37.
#   Batch 1,520  of  8,067.    Elapsed: 0:03:42.
#   Batch 1,560  of  8,067.    Elapsed: 0:03:48.
#   Batch 1,600  of  8,067.    Elapsed: 0:03:54.
#   Batch 1,640  of  8,067.    Elapsed: 0:04:00.
#   Batch 1,680  of  8,067.    Elapsed: 0:04:06.
#   Batch 1,720  of  8,067.    Elapsed: 0:04:12.
#   Batch 1,760  of  8,067.    Elapsed: 0:04:18.
#   Batch 1,800  of  8,067.    Elapsed: 0:04:24.
#   Batch 1,840  of  8,067.    Elapsed: 0:04:29.
#   Batch 1,880  of  8,067.    Elapsed: 0:04:35.
#   Batch 1,920  of  8,067.    Elapsed: 0:04:41.
#   Batch 1,960  of  8,067.    Elapsed: 0:04:47.
#   Batch 2,000  of  8,067.    Elapsed: 0:04:53.
#   Batch 2,040  of  8,067.    Elapsed: 0:04:59.
#   Batch 2,080  of  8,067.    Elapsed: 0:05:05.
#   Batch 2,120  of  8,067.    Elapsed: 0:05:10.
#   Batch 2,160  of  8,067.    Elapsed: 0:05:16.
#   Batch 2,200  of  8,067.    Elapsed: 0:05:22.
#   Batch 2,240  of  8,067.    Elapsed: 0:05:28.
#   Batch 2,280  of  8,067.    Elapsed: 0:05:34.
#   Batch 2,320  of  8,067.    Elapsed: 0:05:40.
#   Batch 2,360  of  8,067.    Elapsed: 0:05:45.
#   Batch 2,400  of  8,067.    Elapsed: 0:05:51.
#   Batch 2,440  of  8,067.    Elapsed: 0:05:57.
#   Batch 2,480  of  8,067.    Elapsed: 0:06:03.
#   Batch 2,520  of  8,067.    Elapsed: 0:06:09.
#   Batch 2,560  of  8,067.    Elapsed: 0:06:15.
#   Batch 2,600  of  8,067.    Elapsed: 0:06:21.
#   Batch 2,640  of  8,067.    Elapsed: 0:06:27.
#   Batch 2,680  of  8,067.    Elapsed: 0:06:32.
#   Batch 2,720  of  8,067.    Elapsed: 0:06:38.
#   Batch 2,760  of  8,067.    Elapsed: 0:06:44.
#   Batch 2,800  of  8,067.    Elapsed: 0:06:50.
#   Batch 2,840  of  8,067.    Elapsed: 0:06:56.
#   Batch 2,880  of  8,067.    Elapsed: 0:07:02.
#   Batch 2,920  of  8,067.    Elapsed: 0:07:08.
#   Batch 2,960  of  8,067.    Elapsed: 0:07:13.
#   Batch 3,000  of  8,067.    Elapsed: 0:07:19.
#   Batch 3,040  of  8,067.    Elapsed: 0:07:25.
#   Batch 3,080  of  8,067.    Elapsed: 0:07:31.
#   Batch 3,120  of  8,067.    Elapsed: 0:07:37.
#   Batch 3,160  of  8,067.    Elapsed: 0:07:43.
#   Batch 3,200  of  8,067.    Elapsed: 0:07:49.
#   Batch 3,240  of  8,067.    Elapsed: 0:07:54.
#   Batch 3,280  of  8,067.    Elapsed: 0:08:00.
#   Batch 3,320  of  8,067.    Elapsed: 0:08:06.
#   Batch 3,360  of  8,067.    Elapsed: 0:08:12.
#   Batch 3,400  of  8,067.    Elapsed: 0:08:18.
#   Batch 3,440  of  8,067.    Elapsed: 0:08:24.
#   Batch 3,480  of  8,067.    Elapsed: 0:08:30.
#   Batch 3,520  of  8,067.    Elapsed: 0:08:36.
#   Batch 3,560  of  8,067.    Elapsed: 0:08:42.
#   Batch 3,600  of  8,067.    Elapsed: 0:08:47.
#   Batch 3,640  of  8,067.    Elapsed: 0:08:53.
#   Batch 3,680  of  8,067.    Elapsed: 0:08:59.
#   Batch 3,720  of  8,067.    Elapsed: 0:09:05.
#   Batch 3,760  of  8,067.    Elapsed: 0:09:11.
#   Batch 3,800  of  8,067.    Elapsed: 0:09:17.
#   Batch 3,840  of  8,067.    Elapsed: 0:09:23.
#   Batch 3,880  of  8,067.    Elapsed: 0:09:28.
#   Batch 3,920  of  8,067.    Elapsed: 0:09:34.
#   Batch 3,960  of  8,067.    Elapsed: 0:09:40.
#   Batch 4,000  of  8,067.    Elapsed: 0:09:46.
#   Batch 4,040  of  8,067.    Elapsed: 0:09:52.
#   Batch 4,080  of  8,067.    Elapsed: 0:09:58.
#   Batch 4,120  of  8,067.    Elapsed: 0:10:03.
#   Batch 4,160  of  8,067.    Elapsed: 0:10:09.
#   Batch 4,200  of  8,067.    Elapsed: 0:10:15.
#   Batch 4,240  of  8,067.    Elapsed: 0:10:21.
#   Batch 4,280  of  8,067.    Elapsed: 0:10:27.
#   Batch 4,320  of  8,067.    Elapsed: 0:10:33.
#   Batch 4,360  of  8,067.    Elapsed: 0:10:39.
#   Batch 4,400  of  8,067.    Elapsed: 0:10:45.
#   Batch 4,440  of  8,067.    Elapsed: 0:10:50.
#   Batch 4,480  of  8,067.    Elapsed: 0:10:56.
#   Batch 4,520  of  8,067.    Elapsed: 0:11:02.
#   Batch 4,560  of  8,067.    Elapsed: 0:11:08.
#   Batch 4,600  of  8,067.    Elapsed: 0:11:14.
#   Batch 4,640  of  8,067.    Elapsed: 0:11:19.
#   Batch 4,680  of  8,067.    Elapsed: 0:11:25.
#   Batch 4,720  of  8,067.    Elapsed: 0:11:31.
#   Batch 4,760  of  8,067.    Elapsed: 0:11:37.
#   Batch 4,800  of  8,067.    Elapsed: 0:11:43.
#   Batch 4,840  of  8,067.    Elapsed: 0:11:49.
#   Batch 4,880  of  8,067.    Elapsed: 0:11:55.
#   Batch 4,920  of  8,067.    Elapsed: 0:12:01.
#   Batch 4,960  of  8,067.    Elapsed: 0:12:06.
#   Batch 5,000  of  8,067.    Elapsed: 0:12:12.
#   Batch 5,040  of  8,067.    Elapsed: 0:12:18.
#   Batch 5,080  of  8,067.    Elapsed: 0:12:24.
#   Batch 5,120  of  8,067.    Elapsed: 0:12:30.
#   Batch 5,160  of  8,067.    Elapsed: 0:12:36.
#   Batch 5,200  of  8,067.    Elapsed: 0:12:41.
#   Batch 5,240  of  8,067.    Elapsed: 0:12:47.
#   Batch 5,280  of  8,067.    Elapsed: 0:12:53.
#   Batch 5,320  of  8,067.    Elapsed: 0:12:59.
#   Batch 5,360  of  8,067.    Elapsed: 0:13:05.
#   Batch 5,400  of  8,067.    Elapsed: 0:13:10.
#   Batch 5,440  of  8,067.    Elapsed: 0:13:16.
#   Batch 5,480  of  8,067.    Elapsed: 0:13:22.
#   Batch 5,520  of  8,067.    Elapsed: 0:13:28.
#   Batch 5,560  of  8,067.    Elapsed: 0:13:34.
#   Batch 5,600  of  8,067.    Elapsed: 0:13:40.
#   Batch 5,640  of  8,067.    Elapsed: 0:13:46.
#   Batch 5,680  of  8,067.    Elapsed: 0:13:52.
#   Batch 5,720  of  8,067.    Elapsed: 0:13:57.
#   Batch 5,760  of  8,067.    Elapsed: 0:14:03.
#   Batch 5,800  of  8,067.    Elapsed: 0:14:09.
#   Batch 5,840  of  8,067.    Elapsed: 0:14:15.
#   Batch 5,880  of  8,067.    Elapsed: 0:14:21.
#   Batch 5,920  of  8,067.    Elapsed: 0:14:27.
#   Batch 5,960  of  8,067.    Elapsed: 0:14:32.
#   Batch 6,000  of  8,067.    Elapsed: 0:14:38.
#   Batch 6,040  of  8,067.    Elapsed: 0:14:44.
#   Batch 6,080  of  8,067.    Elapsed: 0:14:50.
#   Batch 6,120  of  8,067.    Elapsed: 0:14:56.
#   Batch 6,160  of  8,067.    Elapsed: 0:15:02.
#   Batch 6,200  of  8,067.    Elapsed: 0:15:08.
#   Batch 6,240  of  8,067.    Elapsed: 0:15:13.
#   Batch 6,280  of  8,067.    Elapsed: 0:15:19.
#   Batch 6,320  of  8,067.    Elapsed: 0:15:25.
#   Batch 6,360  of  8,067.    Elapsed: 0:15:31.
#   Batch 6,400  of  8,067.    Elapsed: 0:15:37.
#   Batch 6,440  of  8,067.    Elapsed: 0:15:43.
#   Batch 6,480  of  8,067.    Elapsed: 0:15:49.
#   Batch 6,520  of  8,067.    Elapsed: 0:15:54.
#   Batch 6,560  of  8,067.    Elapsed: 0:16:00.
#   Batch 6,600  of  8,067.    Elapsed: 0:16:06.
#   Batch 6,640  of  8,067.    Elapsed: 0:16:12.
#   Batch 6,680  of  8,067.    Elapsed: 0:16:18.
#   Batch 6,720  of  8,067.    Elapsed: 0:16:24.
#   Batch 6,760  of  8,067.    Elapsed: 0:16:30.
#   Batch 6,800  of  8,067.    Elapsed: 0:16:35.
#   Batch 6,840  of  8,067.    Elapsed: 0:16:41.
#   Batch 6,880  of  8,067.    Elapsed: 0:16:47.
#   Batch 6,920  of  8,067.    Elapsed: 0:16:53.
#   Batch 6,960  of  8,067.    Elapsed: 0:16:59.
#   Batch 7,000  of  8,067.    Elapsed: 0:17:05.
#   Batch 7,040  of  8,067.    Elapsed: 0:17:10.
#   Batch 7,080  of  8,067.    Elapsed: 0:17:16.
#   Batch 7,120  of  8,067.    Elapsed: 0:17:22.
#   Batch 7,160  of  8,067.    Elapsed: 0:17:28.
#   Batch 7,200  of  8,067.    Elapsed: 0:17:34.
#   Batch 7,240  of  8,067.    Elapsed: 0:17:40.
#   Batch 7,280  of  8,067.    Elapsed: 0:17:45.
#   Batch 7,320  of  8,067.    Elapsed: 0:17:51.
#   Batch 7,360  of  8,067.    Elapsed: 0:17:57.
#   Batch 7,400  of  8,067.    Elapsed: 0:18:03.
#   Batch 7,440  of  8,067.    Elapsed: 0:18:09.
#   Batch 7,480  of  8,067.    Elapsed: 0:18:15.
#   Batch 7,520  of  8,067.    Elapsed: 0:18:21.
#   Batch 7,560  of  8,067.    Elapsed: 0:18:26.
#   Batch 7,600  of  8,067.    Elapsed: 0:18:32.
#   Batch 7,640  of  8,067.    Elapsed: 0:18:38.
#   Batch 7,680  of  8,067.    Elapsed: 0:18:44.
#   Batch 7,720  of  8,067.    Elapsed: 0:18:50.
#   Batch 7,760  of  8,067.    Elapsed: 0:18:56.
#   Batch 7,800  of  8,067.    Elapsed: 0:19:02.
#   Batch 7,840  of  8,067.    Elapsed: 0:19:08.
#   Batch 7,880  of  8,067.    Elapsed: 0:19:13.
#   Batch 7,920  of  8,067.    Elapsed: 0:19:19.
#   Batch 7,960  of  8,067.    Elapsed: 0:19:25.
#   Batch 8,000  of  8,067.    Elapsed: 0:19:31.
#   Batch 8,040  of  8,067.    Elapsed: 0:19:37.
#
#   Average training loss: 0.36
#   Training epcoh took: 0:19:41
#
# Running Validation...
#   Accuracy: 0.81
#   Validation Loss: 0.39
#   Validation took: 0:01:22
#
# Training complete!
# Total training took 1:03:02 (h:mm:ss)

# %%
preds = []
texts = []
labels = []
for batch in valid_loader:
        
        # Unpack this training batch from our dataloader. 
        #
        # As we unpack the batch, we'll also copy each tensor to the GPU using 
        # the `to` method.
        #
        # `batch` contains three pytorch tensors:
        #   [0]: input ids 
        #   [1]: attention masks
        #   [2]: labels 
        b_input_ids = batch['input_ids'].to(device)
        b_input_mask = batch['attention_mask'].to(device)
        b_labels = batch['targets'].to(device)
        
        # Tell pytorch not to bother with constructing the compute graph during
        # the forward pass, since this is only needed for backprop (training).
        with torch.no_grad():        
            output = model(b_input_ids, 
                                   token_type_ids=None, 
                                   attention_mask=b_input_mask,
                                   labels=b_labels)
            loss = output['loss']
            logits = output['logits']
            logits = logits.detach().cpu().numpy()
            label_ids = b_labels.to('cpu').numpy()
            labels_flat = label_ids.flatten()
            pred_flat = np.argmax(logits, axis=1).flatten()
            preds.extend(pred_flat)
            labels.extend(labels_flat)
            texts.extend(batch['text'])

# %%
import pandas as pd
df = pd.DataFrame({'predictions':preds, 'labels':labels,
                   'texts':texts})

# %%
df.to_csv('binary_predictions.csv', sep='\t')

# %%
import numpy as np
import torch
from transformers import BertTokenizer, BertForSequenceClassification
from torch.utils.data import Dataset, DataLoader
from transformers import AdamW, get_linear_schedule_with_warmup
from tqdm.notebook import tqdm

class BertClassifier:

    def __init__(self, model_path, n_classes=14, epochs=3, batch_size=16, model_save_path='/content/bert_multi.pt'):
        self.model = BertForSequenceClassification.from_pretrained(model_path)
        self.tokenizer = BertTokenizer.from_pretrained(model_path)
        self.device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        self.model_save_path=model_save_path
        self.max_len = 512
        self.epochs = epochs
        self.out_features = self.model.bert.encoder.layer[1].output.dense.out_features
        self.model.classifier = torch.nn.Linear(self.out_features, n_classes)
        self.model.to(self.device)
        self.batch_size = batch_size
    
    def preparation(self, X_train, y_train, X_valid, y_valid):
        # create datasets
        self.train_set = CustomDataset(X_train, y_train, self.tokenizer)
        self.valid_set = CustomDataset(X_valid, y_valid, self.tokenizer)

        # create data loaders
        self.train_loader = DataLoader(self.train_set, batch_size=self.batch_size, shuffle=True)
        self.valid_loader = DataLoader(self.valid_set, batch_size=self.batch_size, shuffle=True)

        # helpers initialization
        self.optimizer = AdamW(self.model.parameters(), lr=2e-5, correct_bias=False)
        self.scheduler = get_linear_schedule_with_warmup(
                self.optimizer,
                num_warmup_steps=0,
                num_training_steps=len(self.train_loader) * self.epochs
            )
        self.loss_fn = torch.nn.CrossEntropyLoss().to(self.device)
            
    def fit(self):
        self.model = self.model.train()
        losses = []
        correct_predictions = 0

        for data in tqdm(self.train_loader):
            input_ids = data["input_ids"].to(self.device)
            attention_mask = data["attention_mask"].to(self.device)
            targets = data["targets"].to(self.device)

            outputs = self.model(
                input_ids=input_ids,
                attention_mask=attention_mask
                )

            preds = torch.argmax(outputs.logits, dim=1)
            loss = self.loss_fn(outputs.logits, targets)

            correct_predictions += torch.sum(preds == targets)

            losses.append(loss.item())
            
            loss.backward()
            torch.nn.utils.clip_grad_norm_(self.model.parameters(), max_norm=1.0)
            self.optimizer.step()
            self.scheduler.step()
            self.optimizer.zero_grad()

        train_acc = correct_predictions.double() / len(self.train_set)
        train_loss = np.mean(losses)
        return train_acc, train_loss
    
    def eval(self):
        self.model = self.model.eval()
        losses = []
        correct_predictions = 0

        with torch.no_grad():
            for data in self.valid_loader:
                input_ids = data["input_ids"].to(self.device)
                attention_mask = data["attention_mask"].to(self.device)
                targets = data["targets"].to(self.device)

                outputs = self.model(
                    input_ids=input_ids,
                    attention_mask=attention_mask
                    )

                preds = torch.argmax(outputs.logits, dim=1)
                loss = self.loss_fn(outputs.logits, targets)
                correct_predictions += torch.sum(preds == targets)
                losses.append(loss.item())
        
        val_acc = correct_predictions.double() / len(self.valid_set)
        val_loss = np.mean(losses)
        return val_acc, val_loss
    
    def train(self):
        best_accuracy = 0
        for epoch in tqdm(range(self.epochs)):
            print(f'Epoch {epoch + 1}/{self.epochs}')
            train_acc, train_loss = self.fit()
            print(f'Train loss {train_loss} accuracy {train_acc}')

            val_acc, val_loss = self.eval()
            print(f'Val loss {val_loss} accuracy {val_acc}')
            print('-' * 10)

            if val_acc > best_accuracy:
                torch.save(self.model, self.model_save_path)
                best_accuracy = val_acc

        self.model = torch.load(self.model_save_path)
    
    def predict(self, text):
        encoding = self.tokenizer.encode_plus(
            text,
            add_special_tokens=True,
            max_length=self.max_len,
            return_token_type_ids=False,
            truncation=True,
            padding='max_length',
            return_attention_mask=True,
            return_tensors='pt',
        )
        
        out = {
              'text': text,
              'input_ids': encoding['input_ids'].flatten(),
              'attention_mask': encoding['attention_mask'].flatten()
          }
        
        input_ids = out["input_ids"].to(self.device)
        attention_mask = out["attention_mask"].to(self.device)
        
        outputs = self.model(
            input_ids=input_ids.unsqueeze(0),
            attention_mask=attention_mask.unsqueeze(0)
        )
        
        prediction = torch.argmax(outputs.logits, dim=1).cpu().numpy()[0]

        return prediction

# %%
from google.colab import drive

drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
nrows = len(train)
total_sample_size = 20000
train_small = train.groupby('Class', as_index=False).\
    apply(lambda x: x.sample(int((len(x)/nrows)*total_sample_size)))

# %%
nrows = len(val)
total_sample_size = 4000
val_small = val.groupby('Class', as_index=False).\
    apply(lambda x: x.sample(int((len(x)/nrows)*total_sample_size)))

# %%
bert = BertClassifier(model_path)
# Out:
# Some weights of the model checkpoint at cointegrated/rubert-tiny were not used when initializing BertForSequenceClassification: ['cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at cointegrated/rubert-tiny and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
train_small['Text'].values.shape
# Out:
# (19993,)

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

# %%
train_small_encoded = encoder.fit_transform(train_small['Class'].values)
val_small_encoded = encoder.transform(val_small['Class'].values)

# %%
bert.preparation(train_small['Text'].values, train_small_encoded, 
                 val_small['Text'].values, val_small_encoded)
bert.train()
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use thePyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
#   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 1/3
#   0%|          | 0/1250 [00:00<?, ?it/s]
# Train loss 1.70507086687088 accuracy 0.4461061371480018
# Val loss 1.512376318216324 accuracy 0.4782064128256513
# ----------
# Epoch 2/3
#   0%|          | 0/1250 [00:00<?, ?it/s]
# Train loss 1.468243408727646 accuracy 0.4938228379932977
# Val loss 1.464912451982498 accuracy 0.49273547094188375
# ----------
# Epoch 3/3
#   0%|          | 0/1250 [00:00<?, ?it/s]
# Train loss 1.4176007950305938 accuracy 0.5085279847946781
# Val loss 1.4538548882007598 accuracy 0.502254509018036
# ----------
